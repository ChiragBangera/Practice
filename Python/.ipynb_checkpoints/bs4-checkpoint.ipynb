# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests as re

# %%
url = ("https://www.amazon.in/Rage-Coffee-Butterscotch-Delight-Flavour/dp/B08Q46TB9S/ref=sr_1_4?crid=10F0UTWL7KI4S&keywords=rage+coffee&qid=1654504910&s=grocery&sprefix=rage+co%2Cgrocery%2C343&sr=1-4")

# %%
HEADERS = ({'User-Agent':
           'Mozilla/5.0 (X11; Linux x86_64)AppleWebKit/537.36 (KHTML, like Gecko)Chrome/44.0.2403.157 Safari/537.36',
                           'Accept-Language': 'en-US, en;q=0.5'})
 
webpage = re.get(url, headers=HEADERS)
soup = BeautifulSoup(webpage.content, "lxml")

# %%
tables  = soup.find_all('table')

# %%
table= tables[0].prettify()
print(table)
# Out:
# <table class="a-lineitem a-align-top">
#  <tr>
#   <td class="a-color-secondary a-size-base a-text-right a-nowrap">
#    M.R.P.:
#   </td>
#   <td class="a-span12 a-color-secondary a-size-base">
#    <span class="a-price a-text-price a-size-base" data-a-color="secondary" data-a-size="b" data-a-strike="true">
#     <span class="a-offscreen">
#      ₹349.00
#     </span>
#     <span aria-hidden="true">
#      ₹349.00
#     </span>
#    </span>
#    <span class="celwidget" data-feature-name="basisPriceLegalMessage" id="basisPriceLegalMessage_feature_div">
#     <span id="listPriceLegalMessage">
#     </span>
#     <style>
#      #listPriceLegalMessageText {
#         margin-left: 5px !important;
#     }
#
#     #listPriceLegalMessage .a-popover-trigger:hover {
#         text-decoration: underline !important;
#     }
#
#     #listPriceLegalMessage .a-icon-popover {
#         display: inline-block !important;
#         margin-left: 0px !important;
#         margin-top: 6px !important;
#     }
#
#     .reinventPrice_legalMessage_icon {
#         width: 12px;
#         fill: #969696;
#         vertical-align: middle;
#         padding-bottom: 2px;
#     }
#
#     .reinventPrice_legalMessage_icon:hover {
#         fill: #555555;
#     }
#     </style>
#     <style type="text/css">
#      .reinventPrice_legalMessage_icon {
#         width: 12px;
#         fill: #969696;
#         vertical-align: middle;
#         padding-bottom: 2px;
#     }
#
#     .reinventPrice_legalMessage_icon:hover {
#         fill: #555555;
#     }
#     </style>
#    </span>
#   </td>
#  </tr>
#  <tr>
#   <td class="a-color-secondary a-size-base a-text-right a-nowrap">
#    Deal of the Day:
#   </td>
#   <td class="a-span12">
#    <span class="a-price a-text-price a-size-medium apexPriceToPay" data-a-color="price" data-a-size="b">
#     <span class="a-offscreen">
#      ₹239.20
#     </span>
#     <span aria-hidden="true">
#      ₹239.20
#     </span>
#    </span>
#    <span class="a-size-small a-color-price">
#     (
#     <span class="a-price a-text-price a-size-small" data-a-color="price" data-a-size="b">
#      <span class="a-offscreen">
#       ₹478.40
#      </span>
#      <span aria-hidden="true">
#       ₹478.40
#      </span>
#     </span>
#     /100 g)
#    </span>
#    <span class="a-size-medium">
#     <span class="celwidget" data-feature-name="jewelryPriceBreakup" id="jewelryPriceBreakup_feature_div">
#     </span>
#     <span class="celwidget" data-feature-name="agsIfdInsidePrice" id="agsIfdInsidePrice_feature_div">
#      <!-- For LightningDeal use case, agsShippingAndIfdInsideBuyBox is only configured on regular offer, so set defaultPageContext as buyingPrice -->
#     </span>
#     <span class="celwidget" data-feature-name="regulatoryDeposit" id="regulatoryDeposit_feature_div">
#     </span>
#     <span class="celwidget" data-feature-name="deliveryPriceBadging" id="deliveryPriceBadging_feature_div">
#     </span>
#     <span class="celwidget" data-feature-name="freeShippingPriceBadging" id="freeShippingPriceBadging_feature_div">
#      <span class="a-size-base">
#      </span>
#     </span>
#     <span class="celwidget" data-feature-name="freeReturns" id="freeReturns_feature_div">
#     </span>
#    </span>
#   </td>
#  </tr>
#  <tr>
#   <td>
#   </td>
#   <td class="a-span12">
#    <div class="a-row" id="dotd_countdown_timer_7b357d16">
#     <span class="a-size-base a-color-base" id="deal_expiry_timer_7b357d16">
#      Ends in  09h 29m 02s
#     </span>
#    </div>
#    <div class="a-row a-hidden" id="dotd_expired_7b357d16">
#     <span class="a-size-base a-color-error">
#      Deal has ended
#     </span>
#    </div>
#    <script type="text/javascript">
#     (function(f) {var _np=(window.P._namespace("GoldboxUDPAssets"));if(_np.guardFatal){_np.guardFatal(f)(_np);}else{f(_np);}}(function(P) {
#
# //this function to be removed after the AUI migration is successful
# function isComponentRegistered(componentName) {
# 	var isRegistered = false;
# 	P.now(componentName).execute(function (module) {
# 		isRegistered = !!module;
# 	});
# 	return isRegistered;
# }
#
# var dealOfferQuantityDropdown = 1;
#
#
#
# P.when('A', 'jQuery', 'udp_ld_widget_js').execute(function(A, $, widget) {
# 	Backbone.setDomLibrary($);
# 	gbResources.registerCustomerData ({
# 		"marketplaceId" : "A21TJRUUN4KGV",
# 		"customerId" : "",
# 		"sessionId" : "262-2900593-3984504",
# 		"csrfToken" : "g82JZbcFreH3wvByLrmET/WZM5/3ittEtdYwjhT6dxBNAAAADAAAAABincEdcmF3AAAAABVX8CwXqz4nuL9RKX///w==",
# 		"aapiCsrfToken" : "1@g0Zaps66oFYVoUawyScUZtEd32cpbtA4EmTlFUTiPV33AAAAAQAAAABincEdcmF3AAAAABVX8CwXqz42z+J7i/ABqA==@NLD_TEQ1Q7",
# 		"claimDealAapiEndpoint" : "https://data.amazon.in/api/marketplaces/A21TJRUUN4KGV/deals/",
# 		"cartCountAapiEndpoint" : "https://data.amazon.in/api/marketplaces/A21TJRUUN4KGV/cart/count",
# 		"cartAddItemsAapiEndpoint" : "https://data.amazon.in/api/marketplaces/A21TJRUUN4KGV/cart/carts/retail/items",
# 		"realm" : "INAmazon",
# 		"isPrimeMember" : false,
# 		"hasEarlyAccessBenefit" : false,
# 		"hasExclusiveAccessBenefit" : false,
# 		"isApp" : false,
# 		"isMobile" : false,
# 		"suppressMultipleStrikeThroughPrices" : false,
# 		"languageOfPreference" : "en-IN"
# 	});
# 	gbResources.registerStrings({
# 		'gbd_ends_in_label' : 'Ends in ',
# 		'gbd_prime_starts_in_label' : 'Starts for all in',
# 		'gbd_hour_label' : 'h',
# 		'gbd_min_label' : 'm',
# 		'gbd_sec_label' : 's',
# 		'gb_starts_in' : 'Starts in',
# 		'gbld-lbl-one-day' : '1 day',
# 		'gbld-lbl-days' : 'days'
# 	});
#
#
# 		if (typeof gbResources.registerApiConfigs == 'function') {
#
# 			gbResources.registerApiConfigs({"CD":{"maxRetries":1,"baseRetryInterval":4000},"GDS":{"maxRetries":0,"baseRetryInterval":60000},"GD":{"maxRetries":1,"baseRetryInterval":4000}});
# 		}
#
#
# 	if (!window.Deal.udpController) {
# 		Deal.udpController = new UDPDealController(Deal.configManager.getControllerConfig(), 'dealContentService/VMF-adapter');
# 	}
#
# 	var widgetName = "udpDealLDWidget";
# 	var udp_deal_widget = Deal.udpController.getWidget(widgetName);
# 	if (udp_deal_widget === undefined || udp_deal_widget === null) {
# 		udp_deal_widget = new UDPDealWidget(widgetName);
# 		Deal.Widgets.push(udp_deal_widget);
# 	}
#
#     udp_deal_widget.setDealId({
#         "dealId" :"7b357d16",
#         "asin" : "B08Q46TB9S",
#         "dealType" : "DEAL_OF_THE_DAY",
#         "primeAccessType" : "",
#         "primeAccessDurationInMs" : 0,
#         "dealStatus": {
#             "7b357d16": {
#                 "dealState": "AVAILABLE",
#                 "msCacheTtl": 12000,
#                 "msToEnd": 34142796,
#                 "msToStart": -33957204,
#                 "dealItemStatus": {
#                     "B08Q46TB9S": {
#                         "customerState": "NONE",
#                         "itemState": "AVAILABLE",
#                         "msToCustomerStateExpiry": 0,
#                         "percentClaimed": 0,
#                     }
#                 }
#             }
#         }
#     });
#
#
#
#     return udp_deal_widget.widgetID;
# });
#
# }));
#    </script>
#   </td>
#  </tr>
#  <tr>
#   <td class="a-color-secondary a-size-base a-text-right a-nowrap">
#    You Save:
#   </td>
#   <td class="a-span12 a-color-price a-size-base">
#    <span class="a-color-price">
#     <span class="a-price a-text-price a-size-base" data-a-color="price" data-a-size="b">
#      <span class="a-offscreen">
#       ₹109.80
#      </span>
#      <span aria-hidden="true">
#       ₹109.80
#      </span>
#     </span>
#     (31%)
#    </span>
#    <span class="celwidget" data-feature-name="bundleLTBSSavings" id="bundleLTBSSavings_feature_div">
#    </span>
#    <span class="celwidget" data-feature-name="volumeAwarePricingTableLoader" id="volumeAwarePricingTableLoader_feature_div">
#    </span>
#   </td>
#  </tr>
#  <tr id="vatMessage">
#   <td>
#   </td>
#   <td>
#    <span class="a-size-base">
#     Inclusive of all taxes
#    </span>
#   </td>
#  </tr>
# </table>

# %%
data = pd.DataFrame(columns=["Weight", "Net Quantity"])
for row in tables[0].find_all('tr'):
    col = row.find_all('td')
    name = row.find_all('th')
    print(name)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [49], in <cell line: 2>()
#       3 col = row.find_all('td')
#       4 name = row.find_all('th')
# ----> 5 print(name[0].text)
#
# IndexError: list index out of range
